# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import os
import csv
from create_dataframe import create_df

# %%
# Create Dataframe
path_images = "./datasets/train/"
path_masks = "./datasets/train/mask/"
path_gt = "./datasets/train/gt/"
df = create_df(path_images,path_masks,path_gt)
df
# Out:
#      UpLeft(Y)  UpLeft(X)  DownRight(Y)  DownRight(X) Type         Imagen  \
# 0       248.85     275.26        289.72        315.17    D  00.000948.jpg
# 1       264.75     139.48        309.74        183.94    D  00.000949.jpg
# 2       113.19    1291.88        175.66       1361.82    B  00.000977.jpg
# 3       113.06    1397.94        191.81       1488.03    B  00.000978.jpg
# 4       115.69    1514.22        215.29       1626.06    B  00.000979.jpg
# 5        74.33     309.05        129.53        364.01    E  00.001145.jpg
# 6        64.94      50.80        148.56        134.77    E  00.001146.jpg
# 7        70.29     183.37        139.97        251.67    E  00.001147.jpg
# 8        46.27     249.94        107.16        309.21    E  00.001150.jpg
# 9        33.71     105.49        111.95        177.88    E  00.001152.jpg
# 10      158.23     388.74        253.26        483.47    D  00.001232.jpg
# 11       84.21      52.03        193.97        143.67    F  00.001250.jpg
# 12       76.77     440.24        154.82        495.30    F  00.001252.jpg
# 13      139.24      65.08        215.41        144.58    D  00.001432.jpg
# 14      115.08     607.15        164.50        656.00    D  00.001433.jpg
# 15      103.07     845.89        140.72        882.07    D  00.001434.jpg
# 16       54.97    1174.63        148.17       1269.18    F  00.001460.jpg
# 17       58.35    1435.04        175.08       1563.20    F  00.001461.jpg
# 18       59.46    1099.59        140.75       1180.20    F  00.001462.jpg
# 19       84.86     106.84        303.98        267.63    F  00.001463.jpg
# 20       88.39     373.12        231.39        470.63    F  00.001464.jpg
# 21       75.41     502.77        183.42        573.29    F  00.001465.jpg
# 22       46.73    1193.54        122.08       1266.35    A  00.001496.jpg
# 23      241.49    1504.69        390.50       1627.92    B  00.001526.jpg
# 24      209.66    1046.92        326.94       1136.44    B  00.001527.jpg
# 25      202.14     580.64        298.60        653.05    B  00.001528.jpg
# 26      184.67    1462.16        308.76       1601.76    A  00.001577.jpg
# 27      101.39    1274.98        180.49       1357.56    A  00.001689.jpg
# 28      110.13    1475.67        212.45       1587.30    A  00.001690.jpg
# 29       83.29    1058.47        138.76       1116.12    A  00.001691.jpg
# ..         ...        ...           ...           ...  ...            ...
# 332     186.08    1472.57        262.71       1551.20    C  01.002618.jpg
# 333     230.25    1491.35        349.37       1599.31    D  01.002632.jpg
# 334     187.77    1440.45        365.86       1609.37    A  01.002641.jpg
# 335     210.40    1133.68        299.32       1220.66    A  01.002642.jpg
# 336     200.49    1084.31        261.87       1151.30    A  01.002656.jpg
# 337     191.54    1186.49        277.91       1278.18    A  01.002658.jpg
# 338     361.62    1047.46        426.55       1121.41    A  01.002659.jpg
# 339     399.70      33.47        433.28         66.20    D  01.002665.jpg
# 340     230.20    1115.92        290.47       1181.37    A  01.002783.jpg
# 341     156.61    1178.75        299.83       1322.81    C  01.002798.jpg
# 342     167.20    1142.73        296.44       1271.12    C  01.002800.jpg
# 343     184.94    1532.96        232.72       1589.44    A  01.002810.jpg
# 344     183.76    1473.49        230.65       1527.45    A  01.002811.jpg
# 345     397.86    1444.56        460.85       1506.57    D  01.002825.jpg
# 346     328.41    1544.75        363.16       1581.36    D  01.002856.jpg
# 347     338.84    1584.66        375.17       1623.91    D  01.002857.jpg
# 348     334.55    1565.26        370.18       1600.79    D  01.002858.jpg
# 349      97.16    1213.48        220.01       1292.66    C  01.002870.jpg
# 350     366.33    1304.82        425.10       1359.31    D  01.002873.jpg
# 351     344.31    1410.61        384.10       1446.73    D  01.002883.jpg
# 352     335.88    1378.92        374.45       1413.82    D  01.002884.jpg
# 353     351.82    1444.41        392.33       1481.66    D  01.002885.jpg
# 354     223.56    1020.81        276.53       1071.24    C  01.002959.jpg
# 355     221.86    1017.85        272.71       1067.00    C  01.002960.jpg
# 356     199.59    1241.59        394.07       1436.76    E  01.003073.jpg
# 357     198.41    1283.17        414.27       1502.07    E  01.003074.jpg
# 358     204.46    1310.53        335.81       1374.93    F  01.003237.jpg
# 359     241.71    1304.18        288.76       1350.65    F  01.003246.jpg
# 360     427.86    1551.92        559.91       1610.30    F  01.003343.jpg
# 361     410.10    1360.59        506.44       1467.29    B  01.003462.jpg
#
#                    Mask
# 0    mask.00.000948.png
# 1    mask.00.000949.png
# 2    mask.00.000977.png
# 3    mask.00.000978.png
# 4    mask.00.000979.png
# 5    mask.00.001145.png
# 6    mask.00.001146.png
# 7    mask.00.001147.png
# 8    mask.00.001150.png
# 9    mask.00.001152.png
# 10   mask.00.001232.png
# 11   mask.00.001250.png
# 12   mask.00.001252.png
# 13   mask.00.001432.png
# 14   mask.00.001433.png
# 15   mask.00.001434.png
# 16   mask.00.001460.png
# 17   mask.00.001461.png
# 18   mask.00.001462.png
# 19   mask.00.001463.png
# 20   mask.00.001464.png
# 21   mask.00.001465.png
# 22   mask.00.001496.png
# 23   mask.00.001526.png
# 24   mask.00.001527.png
# 25   mask.00.001528.png
# 26   mask.00.001577.png
# 27   mask.00.001689.png
# 28   mask.00.001690.png
# 29   mask.00.001691.png
# ..                  ...
# 332  mask.01.002618.png
# 333  mask.01.002632.png
# 334  mask.01.002641.png
# 335  mask.01.002642.png
# 336  mask.01.002656.png
# 337  mask.01.002658.png
# 338  mask.01.002659.png
# 339  mask.01.002665.png
# 340  mask.01.002783.png
# 341  mask.01.002798.png
# 342  mask.01.002800.png
# 343  mask.01.002810.png
# 344  mask.01.002811.png
# 345  mask.01.002825.png
# 346  mask.01.002856.png
# 347  mask.01.002857.png
# 348  mask.01.002858.png
# 349  mask.01.002870.png
# 350  mask.01.002873.png
# 351  mask.01.002883.png
# 352  mask.01.002884.png
# 353  mask.01.002885.png
# 354  mask.01.002959.png
# 355  mask.01.002960.png
# 356  mask.01.003073.png
# 357  mask.01.003074.png
# 358  mask.01.003237.png
# 359  mask.01.003246.png
# 360  mask.01.003343.png
# 361  mask.01.003462.png
#
# [362 rows x 7 columns]

# %% [markdown]
# ## Select Traffic Signs

# %%
img = cv2.imread('./datasets/train/'+df.get_value(0, 'Imagen'),1)
mask = cv2.imread('./datasets/train/mask/'+df.get_value(0, 'Mask'),0)
masked_img = cv2.bitwise_and(img,img,mask = mask)
# Out:
# (1236, 1628)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.show()

# %%
plt.imshow(mask, cmap = 'binary', interpolation = 'bicubic')
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.show()
plt.imshow(cv2.cvtColor(masked_img, cv2.COLOR_BGR2RGB))
plt.show()
